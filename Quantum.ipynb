# %% [markdown]
# ### Quantum

# %% [markdown]
# #### Rules of Quantum Mechanics: (ask Chat to refine into human words)
# 1) The State Vector Rule: The well-defined quantum stte has as many components as there are possible valuyes for any one of types of it's observables.
# Preparing a quanton: puts a quanton in a well defined and normalized quantum state, with a certain number of components.
# 2) The Eigenvector Rule:
# Eigenvector: normalized q-vector associated with any possible numerical value a given observable can have.
# Eigenvalue: the value correspondign to a given eigenvector.
# Any given observable's eigenvectors are mutually orthogonal.
# 3) **The Collapse Rule**:
# By *measuring* the value of a quanton's observables, the measurement determines the value by collapsing the quanton's state randomly to one of the observable's eigenvectors, yielding the result equal to the corresponding eigenvalue.
# Corollary: It is possible to prepare a quanton in a well-defined state by determining the value of one of its observables.
# 4) The Outcome Probability Rule
# 5) The Sequence Rule
# 6) **The Superposition Rule**: In an experiment where a quanton can take either one of two paths from its initial preparation to a final observation and we cannot know which path a given quanton actually took, the total quantom amplitude for the final result is the sum of the two paths' amplitudes.
# 7) The Time Evolution Rule

# %% [markdown]
# ![rulesOfQuantum.png](attachment:rulesOfQuantum.png)
